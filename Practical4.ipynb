# %% [markdown]
# <a href="https://colab.research.google.com/github/Monikagithub26/Reinforcement-Learning/blob/main/Practical4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.seed(1)

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0,50,1000)

# %%
x
# Out:
# array([37, 43, 12,  8,  9, 11,  5, 15,  0, 16,  1, 12,  7, 45,  6, 25, 20,
#        37, 18, 20, 11, 42, 28, 29, 14,  4, 23, 23, 41, 49, 30, 32, 22, 13,
#        41,  9,  7, 22,  1,  0, 17,  8, 24, 13, 47, 42,  8, 30,  7,  3,  6,
#        21, 49,  3,  4, 24, 49, 43, 12, 26, 16, 45, 41, 18, 15,  0,  4, 25,
#        47, 34, 23,  7, 26, 25, 40, 22,  9,  3, 39, 23, 36, 27, 37, 19, 38,
#         8, 32, 34, 10, 23, 15, 47, 23, 25,  7, 28, 10, 46, 32, 24, 23,  1,
#        49, 13,  3,  0, 13,  6, 21,  6,  2, 12, 27, 21, 11,  7, 13,  8, 11,
#        12, 43, 20, 30, 36, 39,  7, 45,  4, 48, 18, 32, 13, 10, 23, 17,  7,
#        24, 10, 28, 20, 32, 12,  1, 30, 41, 24, 18, 33,  2, 44, 28, 39, 34,
#        10, 32, 41, 18, 22,  6,  2,  7, 39, 48, 15,  5, 17, 42, 20, 48, 22,
#        37, 13, 49, 33, 20, 10, 32, 25, 21, 39, 32, 19, 25, 49, 14, 13, 20,
#        43,  6, 13, 15, 24,  9,  2,  7,  5, 36, 37, 21, 40, 13, 27, 49, 49,
# ...

# %%
y = x + np.random.normal(0,10,1000)
#Positive correlation with some noise
y = x + np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81236628],
#        [0.81236628, 1.        ]])

# %% [markdown]
# This correlation is 0,185, a strong positive correlation

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
y = x - np.random.normal(0,10,1000)
#Positive correlation with some noise
y = x - np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.80901668],
#        [0.80901668, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
#1000 random integers between 0 and 50
x = np.random.randint(0,50,1000)

#Negative correlation with some noise 
y = 100 - x + np.random.normal(0,5,1000)
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.94615861],
#        [-0.94615861,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94615861],
#        [-0.94615861,  1.        ]])

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000) # Positively correlated
df['c'] = 100 - df['a'] + np.random.normal(0,5,1000) #negatively correlated
df['d'] = np.random.randint(0,50,1000) #not correlated with 'a'
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.818947 -0.943535  0.026002
# b  0.818947  1.000000 -0.766378 -0.012454
# c -0.943535 -0.766378  1.000000 -0.022904
# d  0.026002 -0.012454 -0.022904  1.000000

# %%
df
# Out:
#       a          b           c   d
# 0     7  -4.926285   91.196743   9
# 1    29  33.626214   70.484212   9
# 2    45  57.317522   43.972530  37
# 3    20  13.938025   80.578738  39
# 4     1  -8.502705  100.669314   4
# ..   ..        ...         ...  ..
# 995  43  42.942232   59.212049  12
# 996  20  29.866643   68.773469  30
# 997  48  51.460677   43.890918  33
# 998  14  10.583041   86.345584  42
# 999   5  19.270824   86.660861   6
#
# [1000 rows x 4 columns]

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
